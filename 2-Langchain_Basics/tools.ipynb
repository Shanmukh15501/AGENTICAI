# %%
from langchain_community.tools import WikipediaQueryRun

# %%
from langchain_community.utilities import WikipediaAPIWrapper

# %%
api_wrapper=WikipediaAPIWrapper(top_k_results=5,doc_content_chars_max= 500)
wiki_tool=WikipediaQueryRun(api_wrapper=api_wrapper)

# %%
wiki_tool.name
# Out:
# 'wikipedia'

# %%
wiki_tool.description
# Out:
# 'A wrapper around Wikipedia. Useful for when you need to answer general questions about people, places, companies, facts, historical events, or other subjects. Input should be a search query.'

# %%
wiki_tool.args
# Out:
# {'query': {'description': 'query to look up on wikipedia',
#   'title': 'Query',
#   'type': 'string'}}

# %%
wiki_tool.run({"query":"elon musk"})
# Out:
# 'Page: Elon Musk\nSummary: Elon Reeve Musk  ( EE-lon; born June 28, 1971) is an international businessman and entrepreneur known for his leadership of Tesla, SpaceX, X (formerly Twitter), and the Department of Government Efficiency (DOGE). Musk has been the wealthiest person in the world since 2021; as of May 2025, Forbes estimates his net worth to be US$424.7 billion.\nBorn to a wealthy family in Pretoria, South Africa, Musk emigrated in 1989 to Canada; he had obtained Canadian citizenship at birt'

# %%
wiki_tool.run("RCB")
# Out:
# d:\PROJECT_PRACTISE_DIRS\AGENTICAI\py_ve_3.11.4\Lib\site-packages\wikipedia\wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file d:\PROJECT_PRACTISE_DIRS\AGENTICAI\py_ve_3.11.4\Lib\site-packages\wikipedia\wikipedia.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# "Page: Royal Challengers Bengaluru\nSummary: Royal Challengers Bengaluru, formerly Royal Challengers Bangalore, also known as RCB, are a professional Twenty20 cricket team based in Bengaluru, Karnataka, that competes in the Indian Premier League (IPL). Founded in 2008 by United Spirits, the team's home ground is M. Chinnaswamy Stadium. They won their first title in 2025. The team finished as the runners-up on three occasions: in 2009, 2011, and 2016. They have also qualified for the playoffs in te"

# %%
from langchain_community.tools import YouTubeSearchTool

# %%
tool=YouTubeSearchTool()

# %%
tool.name
# Out:
# 'youtube_search'

# %%
tool.description
# Out:
# 'search for youtube videos associated with a person. the input to this tool should be a comma separated list, the first part contains a person name and the second a number that is the maximum number of video results to return aka num_results. the second part is optional'

# %%
tool.run("sunny savita")
# Out:
# "['https://www.youtube.com/watch?v=sLEuVm9ZdxQ&pp=ygUMc3Vubnkgc2F2aXRh', 'https://www.youtube.com/watch?v=_kpxLkH5vY0&pp=ygUMc3Vubnkgc2F2aXRh']"

# %%
tool.run("krish naik")
# Out:
# "['https://www.youtube.com/watch?v=JxgmHe2NyeY&pp=ygUKa3Jpc2ggbmFpaw%3D%3D', 'https://www.youtube.com/watch?v=s3KnSb9b4Pk&pp=ygUKa3Jpc2ggbmFpaw%3D%3D']"

# %%
from langchain_community.tools.tavily_search import TavilySearchResults

# %%
import os
TAVILY_API_KEY=os.getenv("TAVILY_API_KEY")

# %%
tool=TavilySearchResults(tavily_api_key=TAVILY_API_KEY)

# %%
tool.invoke({"query":"what happend in RCB victory celebration?"})
# Out:
# [{'title': "Several Killed as RCB's Victory Celebration Turns Deadly At least ...",
#   'url': 'https://www.instagram.com/reel/DKfPDdICusp/',
#   'content': "Log In\n\nSign Up\n\n•\n\nOriginal audio\n\nfirstpost\n\n#VantageOnFirstpost: Several Killed as RCB's Victory Celebration Turns Deadly  \n  \nAt least 11 people were killed and 30 injured in a stampede outside the Chinnaswamy cricket stadium in Bengaluru. The incident happened during the Royal Challengers' victory celebrations after their first IPL triumph in 18 years. Did the state government underestimate the rush? Were crowd control measures not in place?  \n  \n@palkisharmaupadhyay tells you. [...] The police did their best. They had already informed the government authorities and the RCB management not to hold the parade the next day, warning that it could lead to chaos. Unfortunately, their advice was ignored, and the event went ahead as planned. 😢  \nThis entire situation is a result of negligence on the part of the government and the event management. [...] Reply\n\nlloyd\\_looka\n\nPoor planning ushually this kind of victory rally used to be done on the open roads where large number of people can see thier hero this is actually a shame on karanataka government and authorities .\n\nReply\n\nchanda\\_atul11\n\nReally heartbroken\n\nReply\n\nsoulfulamrit",
#   'score': 0.854509},
#  {'title': "Several Killed as RCB's Victory Celebration Turns Deadly - YouTube",
#   'url': 'https://www.youtube.com/watch?v=gz8chxY7elU',
#   'content': "At least 11 people were killed and 30 injured in a stampede outside the Chinnaswamy cricket stadium in Bengaluru. The incident happened during the Royal Challengers' victory celebrations after their first IPL triumph in 18 years. Did the state government underestimate the rush? Were crowd control measures not in place? Palki Sharma tells you. [...] It was supposed to be a day of pure joy, of celebration and pride. Instead, Bengaluru is in shock today. I'm sure you've seen the news and the pictures. Bengaluru was all decked up for a massive celebration today. Their IPL team had finally won the tournament. The Royal Challengers beat Punjab Kings yesterday. It was their first IPL trophy in 18 years. Now the RCB fans are a very passionate lot. Plus they've been waiting for a win since 2008. So they packed the streets of Bengaluru in [...] soon the fan frenzy turned fatal. The exact details are not clear yet but reports say the rush led to a stampede. At least 11 people were killed, including children, and more than 30 were injured. Like I said, the exact sequence of events is unclear, but these pictures give you an idea. Uh you can see fans climbing up fences and trees. In some places, the police pushed back with force. We will show you the pictures, but as always, viewer discretion is advised. [Applause] [Music] [Applause] Such",
#   'score': 0.838376},
#  {'title': "How did celebration of RCB's historic win in IPL spiral into chaos ...",
#   'url': 'https://www.thehindu.com/news/national/karnataka/how-did-celebration-of-rcbs-historic-win-in-ipl-spiral-into-chaos-and-crisis-explained/article69668074.ece',
#   'content': 'August 28, 2025e-Paper\n\nAccount\n\neBooksSubscribeGIFT FRONT PAGE\n\n# How did celebration of RCB’s historic win in IPL spiral into chaos and crisis? | Explained\n\n## A stampede during RCB’s victory celebrations in Bengaluru on June 4 claimed 11 lives and left several others with injuries, turning a moment of triumph into tragedy. Facing a backlash for mismanagement and hurried planning, the Congress government in Karnataka suspended top police officials\n\nPublished - June 07, 2025 04:45 pm IST [...] Though a judicial probe and a Special Investigation Team (SIT) probe have been ordered, serious concerns remain about what exactly led to the deadly chaos and whether it could have been prevented.\n\n#### What went wrong during RCB’s victory celebrations?\n\nA day after RCB’s triumph on June 3, lakhs of fans thronged the M. Chinnaswamy Stadium and also the Vidhana Soudha where the government of Karnataka had organised a separate felicitation event for the RCB team. [...] The situation spiralled out of control when fans, eager to be part of the celebration, rushed to the already packed stadium gates, demanding entry. Overwhelmed by the sheer volume, police personnel struggled to manage the crowd. Chaos broke out as fans jumped barricades, trampled one another, and triggered a deadly stampede, according to police.\n\nAs the tragedy unfolded outside, the event inside the stadium was hastily scaled down and brought to an early close.',
#   'score': 0.8315952},
#  {'title': "RCB's victory celebration turns fatal; 11 fans dead in Bengaluru ...",
#   'url': 'https://www.youtube.com/watch?v=V33zuNSRK14',
#   'content': '# RCB’s victory celebration turns fatal; 11 fans dead in Bengaluru stampede\n## The New Indian Express\n363000 subscribers\n321 likes\n\n### Description\n76226 views\nPosted: 4 Jun 2025\n#stampede #rcb #bengaluru #chinnaswamystadium \n\nThe victory celebrations of Royal Challengers Bengaluru fans turned tragic as more than 11 people including a woman and a boy died in a stampede outside the Chinnaswamy Stadium on Wednesday afternoon. \n\nAlso read: [...] We are active on social media! Follow us:\nFacebook:  \nTwitter: \nAPP: \n\nStay updated with our Apps: \nFor Android users: \niOS users: \n\nFor more videos: \nFor all the important news: \n\n121 comments\n### Transcript:',
#   'score': 0.8252664},
#  {'title': 'The anatomy of a stampede in Bengaluru - The Hindu',
#   'url': 'https://www.thehindu.com/news/national/karnataka/rcb-ipl-victory-celebration-the-anatomy-of-a-stampede-in-bengaluru/article69686157.ece',
#   'content': 'The Chief Minister’s statement that no untoward incident happened at Vidhana Soudha where the State government felicitated the RCB team has been ridiculed by the opposition and drawn much ire from other quarters as well. Siddaramaiah also sacked his political secretary K. Govindaraj, reportedly over his alleged role in organising RCB victory celebrations and shunted out the state intelligence chief. The Chief Minister and Deputy Chief Minister were even summoned by the Congress high command [...] Royal Challengers Bengaluru’s IPL victory celebration in Bengaluru turned tragic with a stampede, leaving 11 dead and 56 injured. _The Hindu_ recounts the sequence of events to analyse how multiple things went wrong in 24 hours\n\nUpdated  - June 14, 2025 06:30 pm IST - Bengaluru\n\nJahnavi T.R.,K. V. Aditya Bharadwaj\n\n    Copy link \n   Email\n    Facebook \n    Twitter \n    Telegram \n    LinkedIn \n    WhatsApp \n    Reddit \n\n0 / 0 New\n\nREAD LATER\n\n Remove SEE ALL\n\nPRINT [...] Image 19: Fans during the RCB victory celebration at Vidhana Soudha in Bengaluru on June 4,  2025.\n\nFans during the RCB victory celebration at Vidhana Soudha in Bengaluru on June 4, 2025. | Photo Credit: Sudhakara Jain',
#   'score': 0.7917732}]

# %%
# Custom_tool

# %%
def multiply(a:int,b:int)->int:
    return a*b

# %%
multiply(10,20)
# Out:
# 200

# %%
multiply.run(10,20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 multiply.run(10,20)
#
# AttributeError: 'function' object has no attribute 'run'

# %%
multiply.invoke(10,20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 multiply.invoke(10,20)
#
# AttributeError: 'function' object has no attribute 'invoke'

# %%
from langchain.agents import tool
@tool
def multiply(a:int,b:int)->int:
    '''this tool is for the multiplication'''
    return a*b

print(type(multiply)) 

print((multiply(1,2)))
# Out:
# <class 'langchain_core.tools.structured.StructuredTool'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[71], line 9
#       5     return a*b
#       7 print(type(multiply))
# ----> 9 print((multiply(1,2)))
#
# File d:\PROJECT_PRACTISE_DIRS\AGENTICAI\py_ve_3.11.4\Lib\site-packages\langchain_core\_api\deprecation.py:191, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     189     warned = True
#     190     emit_warning()
# --> 191 return wrapped(*args, **kwargs)
#
# File d:\PROJECT_PRACTISE_DIRS\AGENTICAI\py_ve_3.11.4\Lib\site-packages\langchain_core\tools\base.py:896, in BaseTool.__call__(self, tool_input, callbacks)
#     893 @deprecated("0.1.47", alternative="invoke", removal="1.0")
#     894 def __call__(self, tool_input: str, callbacks: Callbacks = None) -> str:
#     895     """Make tool callable."""
# --> 896     return self.run(tool_input, callbacks=callbacks)
#
# File d:\PROJECT_PRACTISE_DIRS\AGENTICAI\py_ve_3.11.4\Lib\site-packages\langchain_core\tools\base.py:705, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     667 def run(
#     668     self,
#     669     tool_input: Union[str, dict[str, Any]],
#    (...)    681     **kwargs: Any,
#     682 ) -> Any:
#     683     """Run the tool.
#     684
#     685     Args:
#    (...)    703         ToolException: If an error occurs during tool execution.
#     704     """
# --> 705     callback_manager = CallbackManager.configure(
#     706         callbacks,
#     707         self.callbacks,
#     708         self.verbose or bool(verbose),
#     709         tags,
#     710         self.tags,
#     711         metadata,
#     712         self.metadata,
#     713     )
#     715     run_manager = callback_manager.on_tool_start(
#     716         {"name": self.name, "description": self.description},
#     717         tool_input if isinstance(tool_input, str) else str(tool_input),
#    (...)    726         **kwargs,
#     727     )
#     729     content = None
#
# File d:\PROJECT_PRACTISE_DIRS\AGENTICAI\py_ve_3.11.4\Lib\site-packages\langchain_core\callbacks\manager.py:1625, in CallbackManager.configure(cls, inheritable_callbacks, local_callbacks, verbose, inheritable_tags, local_tags, inheritable_metadata, local_metadata)
#    1594 @classmethod
#    1595 def configure(
#    1596     cls,
#    (...)   1603     local_metadata: Optional[dict[str, Any]] = None,
#    1604 ) -> CallbackManager:
#    1605     """Configure the callback manager.
#    1606
#    1607     Args:
#    (...)   1623         CallbackManager: The configured callback manager.
#    1624     """
# -> 1625     return _configure(
#    1626         cls,
#    1627         inheritable_callbacks,
#    1628         local_callbacks,
#    1629         inheritable_tags,
#    1630         local_tags,
#    1631         inheritable_metadata,
#    1632         local_metadata,
#    1633         verbose=verbose,
#    1634     )
#
# File d:\PROJECT_PRACTISE_DIRS\AGENTICAI\py_ve_3.11.4\Lib\site-packages\langchain_core\callbacks\manager.py:2355, in _configure(callback_manager_cls, inheritable_callbacks, local_callbacks, inheritable_tags, local_tags, inheritable_metadata, local_metadata, verbose)
#    2349     callback_manager = callback_manager_cls(
#    2350         handlers=inheritable_callbacks_.copy(),
#    2351         inheritable_handlers=inheritable_callbacks_.copy(),
#    2352         parent_run_id=parent_run_id,
#    2353     )
#    2354 else:
# -> 2355     parent_run_id_ = inheritable_callbacks.parent_run_id
#    2356     # Break ties between the external tracing context and inherited context
#    2357     if parent_run_id is not None and (
#    2358         parent_run_id_ is None
#    2359         # If the LC parent has already been reflected
#    (...)   2362         or (run_tree and str(parent_run_id_) in run_tree.dotted_order)
#    2363     ):
#
# AttributeError: 'int' object has no attribute 'parent_run_id'

# %%
multiply(1,1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 multiply(1,1)
#
# File d:\PROJECT_PRACTISE_DIRS\AGENTICAI\py_ve_3.11.4\Lib\site-packages\langchain_core\_api\deprecation.py:191, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     189     warned = True
#     190     emit_warning()
# --> 191 return wrapped(*args, **kwargs)
#
# File d:\PROJECT_PRACTISE_DIRS\AGENTICAI\py_ve_3.11.4\Lib\site-packages\langchain_core\tools\base.py:896, in BaseTool.__call__(self, tool_input, callbacks)
#     893 @deprecated("0.1.47", alternative="invoke", removal="1.0")
#     894 def __call__(self, tool_input: str, callbacks: Callbacks = None) -> str:
#     895     """Make tool callable."""
# --> 896     return self.run(tool_input, callbacks=callbacks)
#
# File d:\PROJECT_PRACTISE_DIRS\AGENTICAI\py_ve_3.11.4\Lib\site-packages\langchain_core\tools\base.py:705, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     667 def run(
#     668     self,
#     669     tool_input: Union[str, dict[str, Any]],
#    (...)    681     **kwargs: Any,
#     682 ) -> Any:
#     683     """Run the tool.
#     684
#     685     Args:
#    (...)    703         ToolException: If an error occurs during tool execution.
#     704     """
# --> 705     callback_manager = CallbackManager.configure(
#     706         callbacks,
#     707         self.callbacks,
#     708         self.verbose or bool(verbose),
#     709         tags,
#     710         self.tags,
#     711         metadata,
#     712         self.metadata,
#     713     )
#     715     run_manager = callback_manager.on_tool_start(
#     716         {"name": self.name, "description": self.description},
#     717         tool_input if isinstance(tool_input, str) else str(tool_input),
#    (...)    726         **kwargs,
#     727     )
#     729     content = None
#
# File d:\PROJECT_PRACTISE_DIRS\AGENTICAI\py_ve_3.11.4\Lib\site-packages\langchain_core\callbacks\manager.py:1625, in CallbackManager.configure(cls, inheritable_callbacks, local_callbacks, verbose, inheritable_tags, local_tags, inheritable_metadata, local_metadata)
#    1594 @classmethod
#    1595 def configure(
#    1596     cls,
#    (...)   1603     local_metadata: Optional[dict[str, Any]] = None,
#    1604 ) -> CallbackManager:
#    1605     """Configure the callback manager.
#    1606
#    1607     Args:
#    (...)   1623         CallbackManager: The configured callback manager.
#    1624     """
# -> 1625     return _configure(
#    1626         cls,
#    1627         inheritable_callbacks,
#    1628         local_callbacks,
#    1629         inheritable_tags,
#    1630         local_tags,
#    1631         inheritable_metadata,
#    1632         local_metadata,
#    1633         verbose=verbose,
#    1634     )
#
# File d:\PROJECT_PRACTISE_DIRS\AGENTICAI\py_ve_3.11.4\Lib\site-packages\langchain_core\callbacks\manager.py:2355, in _configure(callback_manager_cls, inheritable_callbacks, local_callbacks, inheritable_tags, local_tags, inheritable_metadata, local_metadata, verbose)
#    2349     callback_manager = callback_manager_cls(
#    2350         handlers=inheritable_callbacks_.copy(),
#    2351         inheritable_handlers=inheritable_callbacks_.copy(),
#    2352         parent_run_id=parent_run_id,
#    2353     )
#    2354 else:
# -> 2355     parent_run_id_ = inheritable_callbacks.parent_run_id
#    2356     # Break ties between the external tracing context and inherited context
#    2357     if parent_run_id is not None and (
#    2358         parent_run_id_ is None
#    2359         # If the LC parent has already been reflected
#    (...)   2362         or (run_tree and str(parent_run_id_) in run_tree.dotted_order)
#    2363     ):
#
# AttributeError: 'int' object has no attribute 'parent_run_id'

# %%
multiply.invoke({"a":10,"b":20})
# Out:
# 200

# %%
multiply.name
# Out:
# 'multiply'

# %%
multiply.description
# Out:
# 'this tool is for the multiplication'

# %%
multiply.args
# Out:
# {'a': {'title': 'A', 'type': 'integer'},
#  'b': {'title': 'B', 'type': 'integer'}}

# %%
def get_word_length(word:str)->int:
    return len(word)

# %%
get_word_length("sunny savita")
# Out:
# 12

# %%
get_word_length("naredra modi")
# Out:
# 12

# %%
@tool
def get_word_length(word:str)->int:
    "Returns length of the word"
    return len(word)
get_word_length("sunny")
# Out:
# 5

# %%
get_word_length.name
# Out:
# 'get_word_length'

# %%
get_word_length.description
# Out:
# 'this funtion is calculating a length of the word'

# %%
get_word_length.args
# Out:
# {'word': {'title': 'Word', 'type': 'string'}}

# %%
get_word_length("sunny")
print(type(get_word_length))  # Will tell you if it's a Tool or a regular function
# Out:
# <class 'langchain_core.tools.structured.StructuredTool'>

# %%
get_word_length.invoke("sunny")
# Out:
# 5
